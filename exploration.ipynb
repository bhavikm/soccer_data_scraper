# %%
import requests
from bs4 import BeautifulSoup
import re
from pprint import pprint


# Set the header so that they think the request is coming from a website
headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.106 Safari/537.36'}

# %%
year = '2011'

# %%
def year_team_links(year):
    page = 'https://www.transfermarkt.co.uk/premier-league/startseite/wettbewerb/GB1/plus/?saison_id=' + year
    tree = requests.get(page, headers = headers)
    soup = BeautifulSoup(tree.content, 'html.parser')

    #Create an empty list to assign the team links to
    teamLinks = []

    #Extract all links with the correct CSS selector
    links = soup.select("a.vereinprofil_tooltip")

    #We need the location that the link is pointing to, so for each link, take the link location. 
    #Additionally, we only need the links in locations 1,3,5,etc. of our list, so loop through those only
    for i in range(1,41,2):
        teamLinks.append(links[i].get("href"))

    #For each location that we have taken, add the website before it - this allows us to call it later
    for i in range(len(teamLinks)):
        teamLinks[i] = "https://www.transfermarkt.co.uk"+teamLinks[i]
        
    return teamLinks

# %%
teamLinks
# Out:
# ['https://www.transfermarkt.co.uk/fc-chelsea/startseite/verein/631/saison_id/2011',
#  'https://www.transfermarkt.co.uk/manchester-city/startseite/verein/281/saison_id/2011',
#  'https://www.transfermarkt.co.uk/manchester-city/startseite/verein/281/saison_id/2011',
#  'https://www.transfermarkt.co.uk/manchester-united/startseite/verein/985/saison_id/2011',
#  'https://www.transfermarkt.co.uk/tottenham-hotspur/startseite/verein/148/saison_id/2011',
#  'https://www.transfermarkt.co.uk/tottenham-hotspur/startseite/verein/148/saison_id/2011',
#  'https://www.transfermarkt.co.uk/fc-arsenal/startseite/verein/11/saison_id/2011',
#  'https://www.transfermarkt.co.uk/fc-liverpool/startseite/verein/31/saison_id/2011',
#  'https://www.transfermarkt.co.uk/fc-liverpool/startseite/verein/31/saison_id/2011',
#  'https://www.transfermarkt.co.uk/fc-everton/startseite/verein/29/saison_id/2011',
#  'https://www.transfermarkt.co.uk/aston-villa/startseite/verein/405/saison_id/2011',
#  'https://www.transfermarkt.co.uk/aston-villa/startseite/verein/405/saison_id/2011',
#  'https://www.transfermarkt.co.uk/afc-sunderland/startseite/verein/289/saison_id/2011',
#  'https://www.transfermarkt.co.uk/newcastle-united/startseite/verein/762/saison_id/2011',
#  'https://www.transfermarkt.co.uk/newcastle-united/startseite/verein/762/saison_id/2011',
#  'https://www.transfermarkt.co.uk/stoke-city/startseite/verein/512/saison_id/2011',
#  'https://www.transfermarkt.co.uk/fc-fulham/startseite/verein/931/saison_id/2011',
#  'https://www.transfermarkt.co.uk/fc-fulham/startseite/verein/931/saison_id/2011',
#  'https://www.transfermarkt.co.uk/queens-park-rangers/startseite/verein/1039/saison_id/2011',
#  'https://www.transfermarkt.co.uk/bolton-wanderers/startseite/verein/355/saison_id/2011']

# %%
def get_team_player_links(year_team_links):
    team_player_links = {}

    #Run the scraper through each of our 20 team links
    for team_link in year_team_links:
        # club from link
        team = team_link.split('/')[3]
        
        #Download and process the team page
        page = team_link
        tree = requests.get(page, headers=headers)
        soup = BeautifulSoup(tree.content, 'html.parser')

        #Extract all links
        links = soup.select("a.spielprofil_tooltip")

        #Create an empty list for our player links to go into
        playerLinks = []

        #For each link, extract the location that it is pointing to
        for j in range(len(links)):
            playerLinks.append(links[j].get("href"))

        #The page list the players more than once - let's use list(set(XXX)) to remove the duplicates
        playerLinks = list(set(playerLinks))

        team_player_links[team] = playerLinks

    return team_player_links

# %%
team_player_links
# Out:
# {'https://www.transfermarkt.co.uk/fc-chelsea/startseite/verein/631/saison_id/2011': ['/branislav-ivanovic/profil/spieler/36827',
#   '/sam-hutchinson/profil/spieler/40617',
#   '/raul-meireles/profil/spieler/13168',
#   '/frank-lampard/profil/spieler/3163',
#   '/ramires/profil/spieler/54170',
#   '/juan-mata/profil/spieler/44068',
#   '/john-mikel-obi/profil/spieler/30739',
#   '/lucas-piazon/profil/spieler/176485',
#   '/david-luiz/profil/spieler/46741',
#   '/salomon-kalou/profil/spieler/7971',
#   '/gary-cahill/profil/spieler/27511',
#   '/yossi-benayoun/profil/spieler/7858',
#   '/alex/profil/spieler/15420',
#   '/ashley-cole/profil/spieler/3182',
#   '/petr-cech/profil/spieler/5658',
#   '/michael-essien/profil/spieler/5588',
#   '/daniel-sturridge/profil/spieler/47082',
#   '/didier-drogba/profil/spieler/3924',
#   '/bosingwa/profil/spieler/9813',
#   '/florent-malouda/profil/spieler/5461',
#   '/jamal-blackman/profil/spieler/128898',
#   '/josh-mceachran/profil/spieler/128905',
#   '/oriol-romeu/profil/spieler/66100',
#   '/john-terry/profil/spieler/3160',
#   '/fernando-torres/profil/spieler/7767',
#   '/nathaniel-chalobah/profil/spieler/128900',
#   '/romelu-lukaku/profil/spieler/96341',
#   '/ross-turnbull/profil/spieler/29159',
#   '/henrique-hilario/profil/spieler/13886',
#   '/ryan-bertrand/profil/spieler/40611',
#   '/paulo-ferreira/profil/spieler/9832',
#   '/nicolas-anelka/profil/spieler/3226'],
#  'https://www.transfermarkt.co.uk/manchester-city/startseite/verein/281/saison_id/2011': ['/david-silva/profil/spieler/35518',
#   '/stefan-savic/profil/spieler/107010',
#   '/david-pizarro/profil/spieler/5896',
#   '/stuart-taylor/profil/spieler/3190',
#   '/luca-scapuzzi/profil/spieler/88709',
#   '/carlos-tevez/profil/spieler/4276',
#   '/karim-rekik/profil/spieler/182579',
#   '/yaya-toure/profil/spieler/13091',
#   '/denis-suarez/profil/spieler/165007',
#   '/nigel-de-jong/profil/spieler/4672',
#   '/joleon-lescott/profil/spieler/4241',
#   '/pablo-zabaleta/profil/spieler/20007',
#   '/gareth-barry/profil/spieler/3291',
#   '/nedum-onuoha/profil/spieler/28810',
#   '/adam-johnson/profil/spieler/31579',
#   '/micah-richards/profil/spieler/32617',
#   '/wayne-bridge/profil/spieler/3682',
#   '/gael-clichy/profil/spieler/7449',
#   '/razak-nuhu/profil/spieler/191935',
#   '/joan-roman/profil/spieler/121411',
#   '/abdul-razak/profil/spieler/177321',
#   '/james-milner/profil/spieler/3333',
#   '/costel-pantilimon/profil/spieler/47659',
#   '/owen-hargreaves/profil/spieler/201',
#   '/emmanuel-adebayor/profil/spieler/8883',
#   '/kolo-toure/profil/spieler/3202',
#   '/sergio-aguero/profil/spieler/26399',
#   '/mario-balotelli/profil/spieler/45146',
#   '/aleksandar-kolarov/profil/spieler/46156',
#   '/samir-nasri/profil/spieler/18935',
#   '/edin-dzeko/profil/spieler/28396',
#   '/dedryck-boyata/profil/spieler/88262',
#   '/michael-johnson/profil/spieler/45274',
#   '/vincent-kompany/profil/spieler/9594',
#   '/joe-hart/profil/spieler/40204',
#   '/shaun-wright-phillips/profil/spieler/3467'],
#  'https://www.transfermarkt.co.uk/manchester-united/startseite/verein/985/saison_id/2011': ['/patrice-evra/profil/spieler/5285',
#   '/fabio/profil/spieler/61891',
#   '/ashley-young/profil/spieler/14086',
#   '/danny-welbeck/profil/spieler/67063',
#   '/jonny-evans/profil/spieler/42412',
#   '/nemanja-vidic-lrm-/profil/spieler/19726',
#   '/tomasz-kuszczak/profil/spieler/1320',
#   '/michael-carrick/profil/spieler/3878',
#   '/mame-diouf/profil/spieler/62049',
#   '/ben-amos/profil/spieler/73472',
#   '/paul-scholes/profil/spieler/3397',
#   '/ravel-morrison/profil/spieler/128907',
#   '/nani/profil/spieler/33706',
#   '/reece-brown/profil/spieler/127996',
#   '/chris-smalling/profil/spieler/103427',
#   '/jesse-lingard/profil/spieler/141660',
#   '/ryan-giggs/profil/spieler/3406',
#   '/federico-macheda/profil/spieler/61887',
#   '/darron-gibson/profil/spieler/42413',
#   '/anderson/profil/spieler/31645',
#   '/will-keane/profil/spieler/118535',
#   '/larnell-cole/profil/spieler/141650',
#   '/michael-owen/profil/spieler/1397',
#   '/michael-keane/profil/spieler/118534',
#   '/ji-sung-park/profil/spieler/4592',
#   '/antonio-valencia/profil/spieler/33544',
#   '/anders-lindegaard/profil/spieler/22491',
#   '/paul-pogba/profil/spieler/122153',
#   '/phil-jones/profil/spieler/117996',
#   '/dimitar-berbatov/profil/spieler/65',
#   '/ritchie-de-laet/profil/spieler/55687',
#   '/rafael/profil/spieler/61892',
#   '/chicharito/profil/spieler/50935',
#   '/darren-fletcher/profil/spieler/3547',
#   '/wayne-rooney/profil/spieler/3332',
#   '/david-de-gea/profil/spieler/59377',
#   '/tom-cleverley/profil/spieler/73484',
#   '/tom-thorpe/profil/spieler/128911',
#   '/rio-ferdinand/profil/spieler/3235',
#   '/zeki-fryers/profil/spieler/141655',
#   '/marnick-vermijl/profil/spieler/110798'],
#  'https://www.transfermarkt.co.uk/tottenham-hotspur/startseite/verein/148/saison_id/2011': ['/roman-pavlyuchenko/profil/spieler/15072',
#   '/dean-parrett/profil/spieler/103487',
#   '/danny-rose/profil/spieler/50174',
#   '/bongani-khumalo/profil/spieler/82215',
#   '/ledley-king/profil/spieler/3360',
#   '/jermaine-jenas/profil/spieler/3461',
#   '/tom-carroll/profil/spieler/121279',
#   '/steven-pienaar/profil/spieler/4321',
#   '/jack-grealish/profil/spieler/203460',
#   '/gabriel-agbonlahor/profil/spieler/37148'],
#  'https://www.transfermarkt.co.uk/afc-sunderland/startseite/verein/289/saison_id/2011': ['/matthew-kilgallon/profil/spieler/4095',
#   '/craig-gardner/profil/spieler/37171',
#   '/stephane-sessegnon/profil/spieler/37157',
#   '/jordan-cook/profil/spieler/61646',
#   '/john-oshea/profil/spieler/3540',
#   '/marcos-angeleri/profil/spieler/27448',
#   '/ahmed-elmohamady/profil/spieler/66333',
#   '/nicklas-bendtner/profil/spieler/34557',
#   '/james-mcclean/profil/spieler/85935',
#   '/george-mccartney/profil/spieler/3775',
#   '/connor-wickham/profil/spieler/95435',
#   '/craig-lynch/profil/spieler/121334',
#   '/dong-won-ji/profil/spieler/164265',
#   '/sotiris-kyrgiakos/profil/spieler/9706',
#   '/sebastian-larsson/profil/spieler/31720',
#   '/wayne-bridge/profil/spieler/3682',
#   '/asamoah-gyan/profil/spieler/26802',
#   '/fraizer-campbell/profil/spieler/42411',
#   '/louis-laing/profil/spieler/110865',
#   '/david-vaughan/profil/spieler/14178',
#   '/keiren-westwood/profil/spieler/15164',
#   '/john-egan/profil/spieler/121324',
#   '/phil-bardsley/profil/spieler/15773',
#   '/lee-cattermole/profil/spieler/37363',
#   '/craig-gordon/profil/spieler/12589',
#   '/david-meyler/profil/spieler/68183',
#   '/trevor-carson/profil/spieler/41131',
#   '/adam-reed/profil/spieler/61667',
#   '/anton-ferdinand/profil/spieler/3698',
#   '/kieran-richardson/profil/spieler/3548',
#   '/jack-colback/profil/spieler/61644',
#   '/titus-bramble/profil/spieler/3130',
#   '/michael-turner/profil/spieler/12127',
#   '/simon-mignolet/profil/spieler/50219',
#   '/wes-brown/profil/spieler/3405',
#   '/ryan-noble/profil/spieler/121340'],
#  'https://www.transfermarkt.co.uk/newcastle-united/startseite/verein/762/saison_id/2011': ['/joey-barton/profil/spieler/3292',
#   '/haris-vuckic/profil/spieler/76560',
#   '/davide-santon/profil/spieler/84344',
#   '/rob-elliot/profil/spieler/39037',
#   '/fraser-forster/profil/spieler/52570',
#   '/mike-williamson/profil/spieler/10642',
#   '/papiss-demba-cisse/profil/spieler/33952',
#   '/james-perch/profil/spieler/49409',
#   '/jeff-henderson/profil/spieler/62062',
#   '/mehdi-abeid/profil/spieler/111036',
#   '/shola-ameobi/profil/spieler/3276',
#   '/danny-guthrie/profil/spieler/16716',
#   '/danny-simpson/profil/spieler/37442',
#   '/paul-dummett/profil/spieler/170321',
#   '/tamas-kadar/profil/spieler/64313',
#   '/hatem-ben-arfa/profil/spieler/18900',
#   '/sammy-ameobi/profil/spieler/92381',
#   '/dan-gosling/profil/spieler/44983',
#   '/tim-krul/profil/spieler/33027',
#   '/steven-taylor/profil/spieler/17273',
#   '/yohan-cabaye/profil/spieler/29434',
#   '/james-tavernier/profil/spieler/62094',
#   '/peter-lovenkrands/profil/spieler/9620',
#   '/demba-ba/profil/spieler/40205',
#   '/cheik-tiote/profil/spieler/33478',
#   '/gabriel-obertan/profil/spieler/43261',
#   '/steve-harper/profil/spieler/3562',
#   '/leon-best/profil/spieler/28244',
#   '/ryan-donaldson/profil/spieler/61569',
#   '/shane-ferguson/profil/spieler/62052',
#   '/fabricio-coloccini/profil/spieler/6150',
#   '/alan-smith/profil/spieler/3768',
#   '/sylvain-marveaux/profil/spieler/39909',
#   '/jonas-gutierrez/profil/spieler/26443',
#   '/ole-soderberg/profil/spieler/62145',
#   '/ryan-taylor/profil/spieler/33785',
#   '/nile-ranger/profil/spieler/88750'],
#  'https://www.transfermarkt.co.uk/stoke-city/startseite/verein/512/saison_id/2011': ['/ryan-shawcross/profil/spieler/45861',
#   '/dean-whitehead/profil/spieler/13683',
#   '/carlo-nash/profil/spieler/3804',
#   '/robert-huth/profil/spieler/2998',
#   '/thomas-sorensen/profil/spieler/3473',
#   '/diego-arismendi/profil/spieler/72645',
#   '/salif-diao/profil/spieler/3600',
#   '/matthew-etherington/profil/spieler/3788',
#   '/ricardo-fuller/profil/spieler/14014',
#   '/matthew-upson/profil/spieler/3273',
#   '/wilson-palacios/profil/spieler/58361',
#   '/rory-delap/profil/spieler/4112',
#   '/danny-higginbotham/profil/spieler/3686',
#   '/andy-wilkinson/profil/spieler/13616',
#   '/ryan-shotton/profil/spieler/92109',
#   '/kenwyne-jones/profil/spieler/28245',
#   '/tom-soares/profil/spieler/15910',
#   '/michael-clarkson/profil/spieler/145483',
#   '/jermaine-pennant/profil/spieler/3195',
#   '/asmir-begovic/profil/spieler/33873',
#   '/peter-crouch/profil/spieler/4072',
#   '/glenn-whelan/profil/spieler/12124',
#   '/marc-wilson/profil/spieler/30456',
#   '/mamady-sidibe/profil/spieler/14069',
#   '/jonathan-walters/profil/spieler/3306',
#   '/danny-collins/profil/spieler/26183',
#   '/michael-tonge/profil/spieler/13544',
#   '/cameron-jerome/profil/spieler/35855',
#   '/andrew-davies/profil/spieler/3869',
#   '/lucas-dawson/profil/spieler/145484',
#   '/jonathan-woodgate/profil/spieler/3224',
#   '/danny-pugh/profil/spieler/3546'],
#  'https://www.transfermarkt.co.uk/fc-fulham/startseite/verein/931/saison_id/2011': ['/steve-sidwell/profil/spieler/13427',
#   '/chris-baird/profil/spieler/4115',
#   '/zdenek-grygera/profil/spieler/6833',
#   '/mark-schwarzer/profil/spieler/3357',
#   '/alexander-kacaniklic/profil/spieler/51040',
#   '/marcel-gecov/profil/spieler/34534',
#   '/orlando-sa/profil/spieler/64535',
#   '/danny-murphy/profil/spieler/3221',
#   '/neil-etheridge/profil/spieler/61694',
#   '/brede-hangeland/profil/spieler/25553',
#   '/simon-davies/profil/spieler/4056',
#   '/damien-duff/profil/spieler/3259',
#   '/mousa-dembele/profil/spieler/19368',
#   '/mahamadou-diarra/profil/spieler/5352',
#   '/david-stockdale/profil/spieler/67339',
#   '/tom-donegan/profil/spieler/121256',
#   '/marcello-trotta/profil/spieler/129505',
#   '/andy-johnson/profil/spieler/14031',
#   '/clint-dempsey/profil/spieler/27577',
#   '/pavel-pogrebnyak/profil/spieler/15074',
#   '/lauri-dalla-valle/profil/spieler/91056',
#   '/matthew-briggs/profil/spieler/51318',
#   '/kerim-frei/profil/spieler/146844',
#   '/stephen-kelly/profil/spieler/12125',
#   '/aaron-hughes/profil/spieler/3580',
#   '/john-arne-riise/profil/spieler/3220',
#   '/bjorn-helge-riise/profil/spieler/13485',
#   '/philippe-senderos/profil/spieler/4277',
#   '/bobby-zamora/profil/spieler/4205',
#   '/csaba-somogyi/profil/spieler/108471',
#   '/dickson-etuhu/profil/spieler/14011',
#   '/jonathan-greening/profil/spieler/3865',
#   '/bryan-ruiz/profil/spieler/39642',
#   '/alex-smith/profil/spieler/116655',
#   '/pajtim-kasami/profil/spieler/130108',
#   '/rafik-halliche/profil/spieler/67815'],
#  'https://www.transfermarkt.co.uk/queens-park-rangers/startseite/verein/1039/saison_id/2011': ['/joey-barton/profil/spieler/3292',
#   '/fitz-hall/profil/spieler/6580',
#   '/kieron-dyer/profil/spieler/3118',
#   '/luke-young/profil/spieler/3271',
#   '/matthew-connolly/profil/spieler/34559',
#   '/rob-hulse/profil/spieler/9980',
#   '/peter-ramage/profil/spieler/28801',
#   '/bruno-perone/profil/spieler/67996',
#   '/taye-taiwo/profil/spieler/28922',
#   '/bradley-orr/profil/spieler/16091',
#   '/samba-diakite/profil/spieler/136589',
#   '/armand-traore/profil/spieler/33783',
#   '/troy-hewitt/profil/spieler/197884',
#   '/patrick-agyemang/profil/spieler/13982',
#   '/alejandro-faurlin/profil/spieler/88067',
#   '/tommy-smith/profil/spieler/12401',
#   '/lee-cook/profil/spieler/13783',
#   '/nedum-onuoha/profil/spieler/28810',
#   '/danny-gabbidon/profil/spieler/12709',
#   '/michael-harriman/profil/spieler/155233',
#   '/federico-macheda/profil/spieler/61887',
#   '/angelo-balanta/profil/spieler/43696',
#   '/djibril-cisse/profil/spieler/3966',
#   '/elvijs-putnins/profil/spieler/120713',
#   '/martin-rowlands/profil/spieler/13734',
#   '/bruno-andrade/profil/spieler/169633',
#   '/adel-taarabt/profil/spieler/45287',
#   '/petter-vaagan-moen/profil/spieler/26422',
#   '/hogan-ephraim/profil/spieler/31883',
#   '/dj-campbell/profil/spieler/37896',
#   '/antonio-german/profil/spieler/105500',
#   '/radek-cerny/profil/spieler/21010',
#   '/jamie-mackie/profil/spieler/15929',
#   '/rowan-vine/profil/spieler/7930',
#   '/kaspars-gorkss/profil/spieler/30379',
#   '/heidar-helguson/profil/spieler/9886',
#   '/shaun-derry/profil/spieler/14007',
#   '/anton-ferdinand/profil/spieler/3698',
#   '/jay-bothroyd/profil/spieler/8188',
#   '/bobby-zamora/profil/spieler/4205',
#   '/danny-shittu/profil/spieler/13736',
#   '/paddy-kenny/profil/spieler/13524',
#   '/jason-puncheon/profil/spieler/47995',
#   '/jordan-gibbons/profil/spieler/198122',
#   '/brian-murphy/profil/spieler/4190',
#   '/clint-hill/profil/spieler/13583',
#   '/shaun-wright-phillips/profil/spieler/3467',
#   '/akos-buzsaky/profil/spieler/13878'],
#  'https://www.transfermarkt.co.uk/bolton-wanderers/startseite/verein/355/saison_id/2011': ['/marvin-sordell/profil/spieler/120599',
#   '/tuncay-sanli/profil/spieler/6934',
#   '/nigel-reo-coker/profil/spieler/14060',
#   '/adam-blakeman/profil/spieler/128228',
#   '/darren-pratley/profil/spieler/28957',
#   '/tyrone-mears/profil/spieler/14050',
#   '/mark-connolly/profil/spieler/128285',
#   '/marcos-alonso/profil/spieler/112515',
#   '/joe-riley/profil/spieler/125117',
#   '/adam-bogdan/profil/spieler/55247',
#   '/paul-robinson/profil/spieler/14063',
#   '/ryo-miyaichi/profil/spieler/129688',
#   '/david-ngog/profil/spieler/41242',
#   '/tim-ream/profil/spieler/145466',
#   '/jussi-jaaskelainen/profil/spieler/3692',
#   '/gary-cahill/profil/spieler/27511',
#   '/gael-kakuta/profil/spieler/74297',
#   '/michael-ohalloran/profil/spieler/125158',
#   '/chris-eagles/profil/spieler/24635',
#   '/david-wheater/profil/spieler/29199',
#   '/zat-knight/profil/spieler/4012',
#   '/robbie-blake/profil/spieler/3490',
#   '/josh-vela/profil/spieler/173804',
#   '/chung-yong-lee/profil/spieler/81801',
#   '/fabrice-muamba/profil/spieler/35586',
#   '/ivan-klasnic/profil/spieler/690',
#   '/stuart-holden/profil/spieler/30071',
#   '/gretar-steinsson/profil/spieler/30304',
#   '/kevin-davies/profil/spieler/4114',
#   '/sam-ricketts/profil/spieler/30434',
#   '/martin-petrov/profil/spieler/670',
#   '/jay-lynch/profil/spieler/128273',
#   '/gregg-wylde/profil/spieler/61030',
#   '/mark-davies/profil/spieler/36917',
#   '/sean-davis/profil/spieler/4036',
#   '/dedryck-boyata/profil/spieler/88262',
#   '/rob-lainton/profil/spieler/65691',
#   '/ricardo-gardner/profil/spieler/6264']}

# %%
# player_link = team_player_links['https://www.transfermarkt.co.uk/fc-chelsea/startseite/verein/631/saison_id/2011'][0]
# print(player_link)

def get_player_data(team_year_player_link):
    # Grab the page 
    page = "https://www.transfermarkt.co.uk"+team_year_player_link
    tree = requests.get(page, headers = headers)
    soup = BeautifulSoup(tree.content, 'html.parser')

    # Grab the player's data
    table = soup.find('table', attrs={'class':'auflistung'})
    table_rows = table.find_all('tr')

    player_data = {}

    # Extract the player's data
    for tr in table_rows:
        th = tr.find_all('th')
        td = tr.find_all('td')
        header = [th.text for th in th]
        data = [tr.text for tr in td]
        row = header + data
        # TODO: I need to save this data instead of printing it 
        player_data[row[0][:-1].strip()] = row[1].strip()
        
    return player_data


def clean_extract_player_data(player_link, raw_player_data, year):
    # player name from link
    player_name = " ".join(player_link.split('/')[1].split('-'))

    dob = datetime.strptime(player_data['Date of birth'], '%b %d, %Y')
    age = int(year) - dob.year

    height = player_data['Height'].encode('ascii', 'ignore')
    height = height[:-1].decode("utf-8").replace(',', '')

    foot = player_data['Foot']
    citizenship = player_data['Citizenship']
    position = player_data['Position']
    
    return player_name, age, height, foot, citizenship, position
    

pprint(player_data)
# Out:
# /branislav-ivanovic/profil/spieler/36827
# {'Age': '36',
#  'Citizenship': 'Serbia',
#  'Contract expires': '30.06.2021',
#  'Current club:': 'West Bromwich Albion',
#  'Date of birth': 'Feb 22, 1984',
#  'Foot': 'right',
#  'Height': '1,85\xa0m',
#  'Joined': 'Sep 15, 2020',
#  'Name in home country': 'Бранислав Ивановић',
#  'Place of birth': 'Sremska Mitrovica',
#  'Player agent': 'Star Management Signings Ltd.',
#  'Position': 'Defender - Centre-Back'}

# %%
# Other data to get: club as at valuedate | Age as at valuedate | Height | Foot | Citizenship
# Out:
# branislav ivanovic
# fc-chelsea
# 185

# %%
# Extract the player's transfer value link
for div in soup.findAll('div', {'class': 'dataMarktwert'}):
    a = div.find('a')
    valuelink = a.attrs['href']
    break

# Get the player's transfer value page
valuepage = "https://www.transfermarkt.co.uk"+valuelink

# TODO: the following error occured
# Traceback (most recent call last):
# File "CompleteEPLPlayerData.py", line 92, in <module>
# Grab the player's transfer page
# AttributeError: 'NoneType' object has no attribute 'group'

# Grab the player's transfer page
tree = requests.get(valuepage, headers=headers)
soup = BeautifulSoup(tree.content, 'html.parser')

# Strip the transfer data (from javascript block)
script = str(soup.findAll('script')[-1])
pattern = "'series':\[(.*)\]"
extract = re.search(pattern, script)
found = extract.group(1)

# Do some magic to turn it into values and store it in a table
stripped = eval(found.replace("\'", "\""))
from pprint import pprint
from datetime import datetime
raw_data = eval(found.replace("\'", "\""))
transfer_value_rows = []
for row in raw_data['data']:
    transfer_value_rows.append((row['y'], datetime.strptime(row['datum_mw'], '%b %d, %Y')))

# ensure sorted by ascending datetime
transfer_value_rows.sort(key=lambda x: x[1])

# get the transfer value 
cuttoff_date = datetime(int(year), 10, 1, 0, 0)
transfer_value_before_cutoff = None
datetime_before_cutoff = None
for value, value_datetime in transfer_value_rows:
    if value_datetime.year == int(year):
        if value_datetime <= cuttoff_date:
            transfer_value_before_cutoff = value
            datetime_before_cutoff = value_datetime
        else:
            break

print(transfer_value_before_cutoff)
# Out:
# [(360000, datetime.datetime(2006, 2, 21, 0, 0)),
#  (3060000, datetime.datetime(2007, 3, 29, 0, 0)),
#  (4950000, datetime.datetime(2007, 8, 23, 0, 0)),
#  (10800000, datetime.datetime(2008, 1, 3, 0, 0)),
#  (6750000, datetime.datetime(2008, 7, 4, 0, 0)),
#  (7650000, datetime.datetime(2009, 6, 29, 0, 0)),
#  (14400000, datetime.datetime(2010, 1, 25, 0, 0)),
#  (16200000, datetime.datetime(2010, 8, 13, 0, 0)),
#  (18900000, datetime.datetime(2011, 2, 1, 0, 0)),
#  (20700000, datetime.datetime(2011, 8, 8, 0, 0)),
#  (16200000, datetime.datetime(2012, 2, 6, 0, 0)),
#  (18900000, datetime.datetime(2012, 6, 24, 0, 0)),
#  (21600000, datetime.datetime(2013, 1, 28, 0, 0)),
#  (19800000, datetime.datetime(2013, 7, 2, 0, 0)),
#  (17100000, datetime.datetime(2014, 1, 15, 0, 0)),
#  (15300000, datetime.datetime(2014, 8, 12, 0, 0)),
#  (15300000, datetime.datetime(2015, 2, 12, 0, 0)),
#  (15300000, datetime.datetime(2015, 7, 1, 0, 0)),
#  (9900000, datetime.datetime(2016, 2, 9, 0, 0)),
#  (9000000, datetime.datetime(2016, 8, 1, 0, 0)),
#  (6300000, datetime.datetime(2017, 2, 5, 0, 0)),
#  (4500000, datetime.datetime(2017, 6, 1, 0, 0)),
#  (3600000, datetime.datetime(2017, 12, 23, 0, 0)),
#  (2700000, datetime.datetime(2018, 6, 6, 0, 0)),
#  (2250000, datetime.datetime(2018, 12, 20, 0, 0)),
#  (1800000, datetime.datetime(2019, 6, 14, 0, 0)),
#  (1350000, datetime.datetime(2019, 12, 23, 0, 0)),
#  (1080000, datetime.datetime(2020, 4, 8, 0, 0)),
#  (900000, datetime.datetime(2020, 7, 29, 0, 0)),
#  (900000, datetime.datetime(2020, 10, 13, 0, 0))]
# 20700000

# %%
# Go through each playerLink and grab their data
for i in range(len(playerLinks)):
    # Grab the page 
    page = "https://www.transfermarkt.co.uk"+playerLinks[i]
    tree = requests.get(page, headers = headers)
    soup = BeautifulSoup(tree.content, 'html.parser')

    # Grab the player's data
    table = soup.find('table', attrs={'class':'auflistung'})
    table_rows = table.find_all('tr')

    # Extract the player's data
    for tr in table_rows:
        th = tr.find_all('th')
        td = tr.find_all('td')
        header = [th.text for th in th]
        data = [tr.text for tr in td]
        row = header + data
        # TODO: I need to save this data instead of printing it 
        print(row)
        
    # Extract the player's transfer value link
    for div in soup.findAll('div', {'class': 'dataMarktwert'}):
        a = div.find('a')
        valuelink = a.attrs['href']
        
    # Get the player's transfer value page
    valuepage = "https://www.transfermarkt.co.uk"+valuelink
    
    # TODO: the following error occured
    # Traceback (most recent call last):
    # File "CompleteEPLPlayerData.py", line 92, in <module>
    # Grab the player's transfer page
    # AttributeError: 'NoneType' object has no attribute 'group'

    # Grab the player's transfer page
    tree = requests.get(valuepage, headers=headers)
    soup = BeautifulSoup(tree.content, 'html.parser')

    # Strip the transfer data (from javascript block)
    script = str(soup.findAll('script')[-1])
    pattern = "'series':\[(.*)\]"
    extract = re.search(pattern, script)
    found = extract.group(1)

    # Do some magic to turn it into values and store it in a table
    stripped = eval(found.replace("\'", "\""))
    from pprint import pprint
    from datetime import datetime
    data = eval(found.replace("\'", "\""))
    rows = []
    for row in data['data']:
        rows.append((row['y'], datetime.strptime(row['datum_mw'], '%b %d, %Y')))

    #TODO: Pass this a date and determine the transfer value FOR the date supplied
    # 1st September [ year ]
    valuedate = '01/09/' + year

    # Store / Output all this data in the following format (to a CSV)
    # SEASON [year] | Player Name | Club as at valuedate | Age as at valuedate | Height | Foot | Citizenship | Transfer value as at valuedate |
